# %% [markdown]
# # Part 1: Data preprocessing

# %% [markdown]
# ## Importing the dataset from Kaggle to Colab

# %% [markdown]
# Dataset link: https://www.kaggle.com/mlg-ulb/creditcardfraud

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('creditcard.csv')

# %% [markdown]
# ## Data Exploration

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
# check the columns
dataset.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# check the information about the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# statistical summary
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Dealing with null values

# %%
# check if there are any null values
dataset.isnull().values.any()
# Out:
# False

# %%
# check how many null values
dataset.isnull().values.sum()
# Out:
# 0

# %%
# show the null values using the heatmap
plt.figure(figsize=(16,9))
sns.heatmap(data=dataset.isnull(), cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Dealing with categorical data

# %%
dataset.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %%
len(dataset.select_dtypes(include=['object']).columns)
# no categorical data
# Out:
# 0

# %% [markdown]
# ## Countplot

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset['Class'].unique()
# Out:
# array([0, 1])

# %%
# Create a countplot
sns.countplot(data=dataset, x='Class', label='Count')

# Set labels for the x-axis
plt.xticks([0, 1], ["Not Fraudelent",'Fraudulent'])

# Show the plot
plt.show()

# %%
# Non fraud transactions
(dataset.Class == 0).sum()
# Out:
# 284315

# %%
# Fraud transactions
(dataset.Class == 1).sum()
# Out:
# 492

# %% [markdown]
# ## Correlation matrix and Heatmap

# %%
dataset_2 = dataset.drop(columns=['Class'])

# %%
dataset_2.corrwith(dataset['Class']).plot.bar(
    figsize=(16,9), title = 'Correlation with class',
    rot = 45, grid = True
)
# Out:
# <Axes: title={'center': 'Correlation with class'}>

# %%
# Create Correlation Matrix
corr = dataset.corr()

# %%
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# V12     0.124348  2.053457e-16 -9.568710e-17  6.310231e-16 -5.625518e-16
# V13    -0.065902 -2.425603e-17  6.295388e-16  2.807652e-16  1.303306e-16
# V14    -0.098757 -5.020280e-16 -1.730566e-16  4.739859e-16  2.282280e-16
# V15    -0.183453  3.547782e-16 -4.995814e-17  9.068793e-16  1.377649e-16
# V16     0.011903  7.212815e-17  1.177316e-17  8.299445e-16 -9.614528e-16
# V17    -0.073297 -3.879840e-16 -2.685296e-16  7.614712e-16 -2.699612e-16
# V18     0.090438  3.230206e-17  3.284605e-16  1.509897e-16 -5.103644e-16
# V19     0.028975  1.502024e-16 -7.118719e-18  3.463522e-16 -3.980557e-16
# V20    -0.050866  4.654551e-16  2.506675e-16 -9.316409e-16 -1.857247e-16
# V21     0.044736 -2.457409e-16 -8.480447e-17  5.706192e-17 -1.949553e-16
# V22     0.144059 -4.290944e-16  1.526333e-16 -1.133902e-15 -6.276051e-17
# V23     0.051142  6.168652e-16  1.634231e-16 -4.983035e-16  9.164206e-17
# V24    -0.016182 -4.425156e-17  1.247925e-17  2.686834e-19  1.584638e-16
# V25    -0.233083 -9.605737e-16 -4.478846e-16 -1.104734e-15  6.070716e-16
# V26    -0.041407 -1.581290e-17  2.057310e-16 -1.238062e-16 -4.247268e-16
# V27    -0.005135  1.198124e-16 -4.966953e-16  1.045747e-15  3.977061e-17
# V28    -0.009413  2.083082e-15 -5.093836e-16  9.775546e-16 -2.761403e-18
# Amount -0.010596 -2.277087e-01 -5.314089e-01 -2.108805e-01  9.873167e-02
# Class  -0.012323 -1.013473e-01  9.128865e-02 -1.929608e-01  1.334475e-01
#
#                   V5            V6            V7            V8            V9  \
# Time    1.730721e-01 -6.301647e-02  8.471437e-02 -3.694943e-02 -8.660434e-03
# V1      1.812612e-17 -6.506567e-16 -1.005191e-15 -2.433822e-16 -1.513678e-16
# V2      5.157519e-16  2.787346e-16  2.055934e-16 -5.377041e-17  1.978488e-17
# V3     -6.539009e-17  1.627627e-15  4.895305e-16 -1.268779e-15  5.568367e-16
# V4     -1.719944e-15 -7.491959e-16 -4.104503e-16  5.697192e-16  6.923247e-16
# V5      1.000000e+00  2.408382e-16  2.715541e-16  7.437229e-16  7.391702e-16
# V6      2.408382e-16  1.000000e+00  1.191668e-16 -1.104219e-16  4.131207e-16
# V7      2.715541e-16  1.191668e-16  1.000000e+00  3.344412e-16  1.122501e-15
# V8      7.437229e-16 -1.104219e-16  3.344412e-16  1.000000e+00  4.356078e-16
# V9      7.391702e-16  4.131207e-16  1.122501e-15  4.356078e-16  1.000000e+00
# V10    -5.202306e-16  5.932243e-17 -7.492834e-17 -2.801370e-16 -4.642274e-16
# V11     7.203963e-16  1.980503e-15  1.425248e-16  2.487043e-16  1.354680e-16
# V12     7.412552e-16  2.375468e-16 -3.536655e-18  1.839891e-16 -1.079314e-15
# V13     5.886991e-16 -1.211182e-16  1.266462e-17 -2.921856e-16  2.251072e-15
# V14     6.565143e-16  2.621312e-16  2.607772e-16 -8.599156e-16  3.784757e-15
# V15    -8.720275e-16 -1.531188e-15 -1.690540e-16  4.127777e-16 -1.051167e-15
# V16     2.246261e-15  2.623672e-18  5.869302e-17 -5.254741e-16 -1.214086e-15
# V17     1.281914e-16  2.015618e-16  2.177192e-16 -2.269549e-16  1.113695e-15
# V18     5.308590e-16  1.223814e-16  7.604126e-17 -3.667974e-16  4.993240e-16
# V19    -1.450421e-16 -1.865597e-16 -1.881008e-16 -3.875186e-16 -1.376135e-16
# V20    -3.554057e-16 -1.858755e-16  9.379684e-16  2.033737e-16 -2.343720e-16
# V21    -3.920976e-16  5.833316e-17 -2.027779e-16  3.892798e-16  1.936953e-16
# V22     1.253751e-16 -4.705235e-19 -8.898922e-16  2.026927e-16 -7.071869e-16
# V23    -8.428683e-18  1.046712e-16 -4.387401e-16  6.377260e-17 -5.214137e-16
# V24    -1.149255e-15 -1.071589e-15  7.434913e-18 -1.047097e-16 -1.430343e-16
# V25     4.808532e-16  4.562861e-16 -3.094082e-16 -4.653279e-16  6.757763e-16
# V26     4.319541e-16 -1.357067e-16 -9.657637e-16 -1.727276e-16 -7.888853e-16
# V27     6.590482e-16 -4.452461e-16 -1.782106e-15  1.299943e-16 -6.709655e-17
# V28    -5.613951e-18  2.594754e-16 -2.776530e-16 -6.200930e-16  1.110541e-15
# Amount -3.863563e-01  2.159812e-01  3.973113e-01 -1.030791e-01 -4.424560e-02
# Class  -9.497430e-02 -4.364316e-02 -1.872566e-01  1.987512e-02 -9.773269e-02
#
#         ...           V21           V22           V23           V24  \
# Time    ...  4.473573e-02  1.440591e-01  5.114236e-02 -1.618187e-02
# V1      ... -2.457409e-16 -4.290944e-16  6.168652e-16 -4.425156e-17
# V2      ... -8.480447e-17  1.526333e-16  1.634231e-16  1.247925e-17
# V3      ...  5.706192e-17 -1.133902e-15 -4.983035e-16  2.686834e-19
# V4      ... -1.949553e-16 -6.276051e-17  9.164206e-17  1.584638e-16
# V5      ... -3.920976e-16  1.253751e-16 -8.428683e-18 -1.149255e-15
# V6      ...  5.833316e-17 -4.705235e-19  1.046712e-16 -1.071589e-15
# V7      ... -2.027779e-16 -8.898922e-16 -4.387401e-16  7.434913e-18
# V8      ...  3.892798e-16  2.026927e-16  6.377260e-17 -1.047097e-16
# V9      ...  1.936953e-16 -7.071869e-16 -5.214137e-16 -1.430343e-16
# V10     ...  1.177547e-15 -6.418202e-16  3.214491e-16 -1.355885e-16
# V11     ... -5.658364e-16  7.772895e-16 -4.505332e-16  1.933267e-15
# V12     ...  7.300527e-16  1.644699e-16  1.800885e-16  4.436512e-16
# V13     ...  1.008461e-16  6.747721e-17 -7.132064e-16 -1.397470e-16
# V14     ... -3.356561e-16  3.740383e-16  3.883204e-16  2.003482e-16
# V15     ...  6.605263e-17 -4.208921e-16 -3.912243e-16 -4.478263e-16
# V16     ... -4.715090e-16 -7.923387e-17  5.020770e-16 -3.005985e-16
# V17     ... -8.230527e-16 -8.743398e-16  3.706214e-16 -2.403828e-16
# V18     ... -9.408680e-16 -4.819365e-16 -1.912006e-16 -8.986916e-17
# V19     ...  5.115885e-16 -1.163768e-15  7.032035e-16  2.587708e-17
# V20     ... -7.614597e-16  1.009285e-15  2.712885e-16  1.277215e-16
# V21     ...  1.000000e+00  3.649908e-15  8.119580e-16  1.761054e-16
# V22     ...  3.649908e-15  1.000000e+00 -7.303916e-17  9.970809e-17
# V23     ...  8.119580e-16 -7.303916e-17  1.000000e+00  2.130519e-17
# V24     ...  1.761054e-16  9.970809e-17  2.130519e-17  1.000000e+00
# V25     ... -1.686082e-16 -5.018575e-16 -8.232727e-17  1.015391e-15
# V26     ... -5.557329e-16 -2.503187e-17  1.114524e-15  1.343722e-16
# V27     ... -1.211281e-15  8.461337e-17  2.839721e-16 -2.274142e-16
# V28     ...  5.278775e-16 -6.627203e-16  1.481903e-15 -2.819805e-16
# Amount  ...  1.059989e-01 -6.480065e-02 -1.126326e-01  5.146217e-03
# Class   ...  4.041338e-02  8.053175e-04 -2.685156e-03 -7.220907e-03
#
#                  V25           V26           V27           V28    Amount  \
# Time   -2.330828e-01 -4.140710e-02 -5.134591e-03 -9.412688e-03 -0.010596
# V1     -9.605737e-16 -1.581290e-17  1.198124e-16  2.083082e-15 -0.227709
# V2     -4.478846e-16  2.057310e-16 -4.966953e-16 -5.093836e-16 -0.531409
# V3     -1.104734e-15 -1.238062e-16  1.045747e-15  9.775546e-16 -0.210880
# V4      6.070716e-16 -4.247268e-16  3.977061e-17 -2.761403e-18  0.098732
# V5      4.808532e-16  4.319541e-16  6.590482e-16 -5.613951e-18 -0.386356
# V6      4.562861e-16 -1.357067e-16 -4.452461e-16  2.594754e-16  0.215981
# V7     -3.094082e-16 -9.657637e-16 -1.782106e-15 -2.776530e-16  0.397311
# V8     -4.653279e-16 -1.727276e-16  1.299943e-16 -6.200930e-16 -0.103079
# V9      6.757763e-16 -7.888853e-16 -6.709655e-17  1.110541e-15 -0.044246
# V10    -2.846052e-16 -3.028119e-16 -2.197977e-16  4.864782e-17 -0.101502
# V11    -5.600475e-16 -1.003221e-16 -2.640281e-16 -3.792314e-16  0.000104
# V12    -5.712973e-16 -2.359969e-16 -4.672391e-16  6.415167e-16 -0.009542
# V13    -5.497612e-16 -1.769255e-16 -4.720898e-16  1.144372e-15  0.005293
# V14    -8.547932e-16 -1.660327e-16  1.044274e-16  2.289427e-15  0.033751
# V15     3.206423e-16  2.817791e-16 -1.143519e-15 -1.194130e-15 -0.002986
# V16    -1.345418e-15 -7.290010e-16  6.789513e-16  7.588849e-16 -0.003910
# V17     2.666806e-16  6.932833e-16  6.148525e-16 -5.534540e-17  0.007309
# V18    -6.629212e-17  2.990167e-16  2.242791e-16  7.976796e-16  0.035650
# V19     9.577163e-16  5.898033e-16 -2.959370e-16 -1.405379e-15 -0.056151
# V20     1.410054e-16 -2.803504e-16 -1.138829e-15 -2.436795e-16  0.339403
# V21    -1.686082e-16 -5.557329e-16 -1.211281e-15  5.278775e-16  0.105999
# V22    -5.018575e-16 -2.503187e-17  8.461337e-17 -6.627203e-16 -0.064801
# V23    -8.232727e-17  1.114524e-15  2.839721e-16  1.481903e-15 -0.112633
# V24     1.015391e-15  1.343722e-16 -2.274142e-16 -2.819805e-16  0.005146
# V25     1.000000e+00  2.646517e-15 -6.406679e-16 -7.008939e-16 -0.047837
# V26     2.646517e-15  1.000000e+00 -3.667715e-16 -2.782204e-16 -0.003208
# V27    -6.406679e-16 -3.667715e-16  1.000000e+00 -3.061287e-16  0.028825
# V28    -7.008939e-16 -2.782204e-16 -3.061287e-16  1.000000e+00  0.010258
# Amount -4.783686e-02 -3.208037e-03  2.882546e-02  1.025822e-02  1.000000
# Class   3.307706e-03  4.455398e-03  1.757973e-02  9.536041e-03  0.005632
#
#            Class
# Time   -0.012323
# V1     -0.101347
# V2      0.091289
# V3     -0.192961
# V4      0.133447
# V5     -0.094974
# V6     -0.043643
# V7     -0.187257
# V8      0.019875
# V9     -0.097733
# V10    -0.216883
# V11     0.154876
# V12    -0.260593
# V13    -0.004570
# V14    -0.302544
# V15    -0.004223
# V16    -0.196539
# V17    -0.326481
# V18    -0.111485
# V19     0.034783
# V20     0.020090
# V21     0.040413
# V22     0.000805
# V23    -0.002685
# V24    -0.007221
# V25     0.003308
# V26     0.004455
# V27     0.017580
# V28     0.009536
# Amount  0.005632
# Class   1.000000
#
# [31 rows x 31 columns]

# %%
# correlation heatmap
plt.figure(figsize=(30,30))
ax = sns.heatmap(corr, annot=True, linewidths=2)

# %%
# Set Up Mask To Hide Upper Triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(32,18))
ax = sns.heatmap(corr, mask=mask, annot=True, linewidths=0.5, cmap = 'coolwarm')

# %% [markdown]
# ## Split the dataset into train and test set

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# independent variables
x = dataset.iloc[:, :-1].values

# %%
x.shape
# Out:
# (284807, 30)

# %%
# dependent variable
y = dataset.iloc[:, -1].values

# %%
y.shape
# Out:
# (284807,)

# %%
# split the dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (227845, 30)

# %%
x_test.shape
# Out:
# (56962, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_test.shape
# Out:
# (56962,)

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.87750986, -0.57177938,  0.62828369, ...,  0.57377804,
#         -0.2196612 , -0.30511629],
#        [-1.15308534,  0.62679248, -0.08362249, ..., -0.17091545,
#          0.00631402, -0.25423683],
#        [ 1.26383162,  0.98361214, -0.1198731 , ...,  0.13283995,
#         -0.10128286, -0.32950779],
#        ...,
#        [-0.38349503,  0.77210803, -0.57499928, ..., -0.00209668,
#          0.01184758, -0.21662151],
#        [ 0.05096267,  0.91851362, -1.02985151, ..., -0.08231776,
#         -0.10081197,  0.33333622],
#        [-0.41989457, -0.30294167,  0.45385207, ...,  0.21715744,
#          0.36857129, -0.29286006]])

# %%
x_test
# Out:
# array([[ 0.65238668, -0.16686457,  0.64154241, ...,  0.27172397,
#          0.50280513, -0.19606009],
#        [ 1.31372573, -0.18035885,  0.56586861, ...,  0.19283776,
#          0.54777109, -0.34934352],
#        [ 1.21343225, -0.82732765, -1.45828848, ...,  0.7146577 ,
#          1.36386022,  0.02971246],
#        ...,
#        [ 0.89086789,  0.57407801, -1.38701874, ..., -0.5986488 ,
#         -0.02294377,  1.99397392],
#        [ 1.39073528,  1.05455377,  0.17341371, ..., -0.2555804 ,
#         -0.19207626, -0.34543281],
#        [ 1.22637946,  1.20109412, -0.80279701, ...,  0.01953937,
#         -0.16055905, -0.2968514 ]])

# %% [markdown]
# # Part 2: Building the model

# %% [markdown]
# ## 1) Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier_lr = LogisticRegression(random_state = 0)
classifier_lr.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier_lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

results_list = []
model_results = pd.DataFrame([['Logistic Regression', acc, prec, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
results_list.append(model_results)
results = pd.concat(results_list, ignore_index=True)

# %%
results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.999192   0.876712  0.633663  0.735632

# %% [markdown]
# ### K-fold Cross validation and confusion matrix

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier_lr, X=x_train, y=y_train, cv=10)

print("Accuracy is {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation is {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy is 99.92 %
# Standard Deviation is 0.02 %

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[56852     9]
#  [   37    64]]

# %% [markdown]
# ## 2) Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state = 0, n_estimators = 10,
                                    criterion = 'entropy')
classifier_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier_rf.predict(x_test)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['Random Forest', acc, prec, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

results_list.append(model_results)
results = pd.concat(results_list, ignore_index=True)

results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.999192   0.876712  0.633663  0.735632
# 1        Random Forest  0.999456   0.916667  0.762376  0.832432

# %% [markdown]
# ### K-fold Cross validation and confusion matrix

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier_rf, X=x_train, y=y_train, cv=10)
print("Accuracy is {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation is {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy is 99.95 %
# Standard Deviation is 0.01 %

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[56854     7]
#  [   24    77]]

# %% [markdown]
# ## 3) XGBoost

# %%
from xgboost import XGBClassifier
classifier_xgb = XGBClassifier()
classifier_xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = classifier_xgb.predict(x_test)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['XGBoost', acc, prec, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

results_list.append(model_results)

results = pd.concat(results_list, ignore_index=True)

results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.999192   0.876712  0.633663  0.735632
# 1        Random Forest  0.999456   0.916667  0.762376  0.832432
# 2              XGBoost  0.999544   0.921348  0.811881  0.863158

# %% [markdown]
# ### K-fold Cross validation and confusion matrix

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier_xgb, X=x_train, y=y_train, cv=10)

print("Accuracy is {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation is {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy is 99.96 %
# Standard Deviation is 0.01 %

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[56854     7]
#  [   19    82]]

# %% [markdown]
# # Part 4: Applying Randomized Search to find the best parameters

# %% [markdown]
# 1. Parameters in XGboost: https://xgboost.readthedocs.io/en/latest/parameter.html#general-parameters

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters ={
    'learning_rate': [0.05, 0.10, 0.15, 0.20, 0.25, 0.30],
    'max_depth':[3, 4, 5, 6, 8, 10, 12, 15],
    'min_child_weight':[1, 3, 5, 7],
    'gamma':[0.0, 0.1, 0.2 , 0.3, 0.4],
    'colsample_bytree':[0.3, 0.4, 0.5 , 0.7]
    }

# %%
randomized_search = RandomizedSearchCV(estimator = classifier_xgb, param_distributions = parameters,
                                 n_iter = 5, scoring='roc_auc', n_jobs = -1, cv = 5, verbose=3)

# cv: cross-validation
# n_jobs = -1:
# Number of jobs to run in parallel. -1 means using all processors

# %%
randomized_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=1;, score=0.971 total time=   6.0s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=1;, score=0.973 total time=   6.2s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=1;, score=0.967 total time=   6.2s
# [CV 2/5] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=8, min_child_weight=7;, score=0.975 total time=   7.3s
# [CV 1/5] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=8, min_child_weight=7;, score=0.971 total time=   7.5s
# [CV 5/5] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=8, min_child_weight=7;, score=0.984 total time=   7.5s
# [CV 4/5] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=8, min_child_weight=7;, score=0.988 total time=   7.7s
# [CV 3/5] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=8, min_child_weight=7;, score=0.984 total time=   8.0s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=1;, score=0.985 total time=   7.4s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=1;, score=0.989 total time=   7.5s
# [CV 1/5] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=8, min_child_weight=5;, score=0.978 total time=   7.0s
# [CV 1/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5;, score=0.971 total time=   8.9s
# [CV 3/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5;, score=0.976 total time=   8.4s
# [CV 2/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5;, score=0.974 total time=   8.7s
# [CV 4/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5;, score=0.988 total time=   8.5s
# [CV 5/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=5;, score=0.982 total time=   8.4s
# [CV 2/5] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=8, min_child_weight=5;, score=0.967 total time=   6.9s
# [CV 3/5] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=8, min_child_weight=5;, score=0.977 total time=   6.9s
# [CV 4/5] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=8, min_child_weight=5;, score=0.973 total time=   6.4s
# [CV 5/5] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=8, min_child_weight=5;, score=0.992 total time=   6.5s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.25, max_depth=12, min_child_weight=5;, score=0.974 total time=   7.0s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.25, max_depth=12, min_child_weight=5;, score=0.966 total time=   7.1s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.25, max_depth=12, min_child_weight=5;, score=0.985 total time=   6.9s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.25, max_depth=12, min_child_weight=5;, score=0.972 total time=   7.0s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.25, max_depth=12, min_child_weight=5;, score=0.986 total time=   4.0s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25, 0.3],
#                                         'max_depth': [3, 4, 5, 6, 8, 10, 12,
#                                                       15],
#                                         'min_child_weight': [1, 3, 5, 7]},
#                    scoring='roc_auc', verbose=3)

# %%
randomized_search.best_estimator_
# all the params that are selected by the randomized_search for that XGB Classifier
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.2, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
randomized_search.best_params_
# Out:
# {'min_child_weight': 7,
#  'max_depth': 8,
#  'learning_rate': 0.2,
#  'gamma': 0.2,
#  'colsample_bytree': 0.5}

# %%
randomized_search.best_score_
# Out:
# 0.9801664257268307

# %% [markdown]
# # Part 5: Final Model (XGBoost)

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.5, gamma=0.0,
              learning_rate=0.2, max_delta_step=0, max_depth=12,
              min_child_weight=7, missing=None, n_estimators=100, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1)

classifier.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=0, max_depth=12,
#               max_leaves=None, min_child_weight=7, missing=None,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=1, nthread=None, num_parallel_tree=None, ...)

# %%
y_pred = classifier_xgb.predict(x_test)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['Final Model(XGBoost)', acc, prec, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

results_list.append(model_results)

results = pd.concat(results_list, ignore_index=True)

results
# Out:
#                    Model  Accuracy  Precision    Recall  F1 Score
# 0    Logistic Regression  0.999192   0.876712  0.633663  0.735632
# 1          Random Forest  0.999456   0.916667  0.762376  0.832432
# 2                XGBoost  0.999544   0.921348  0.811881  0.863158
# 3  Final Model (XGBoost)  0.999544   0.921348  0.811881  0.863158

# %% [markdown]
# ## k-fold cross validation and confusion matrix

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier, X=x_train, y=y_train, cv=10)

print("Accuracy is {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation is {:.2f} %".format(accuracies.std()*100))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:40] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:42] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:45] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:47] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:49] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:52] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:54] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:57] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:58:59] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(
# Accuracy is nan %
# Standard Deviation is nan %
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:842: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer(estimator, *args, **routed_params.get(name).score)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1549, in predict
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1164, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2435, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 281, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [07:59:02] /Users/runner/work/xgboost/xgboost/include/xgboost/json.h:630: Invalid type for: `missing`, expecting one of the: {``Number`, `Integer`}, got: `Null`
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001695f11e8 dmlc::LogMessageFatal::~LogMessageFatal() + 124
#   [bt] (1) 2   libxgboost.dylib                    0x00000001695fa1d4 void xgboost::TypeCheck<xgboost::JsonNumber, xgboost::JsonInteger>(xgboost::Json const&, xgboost::StringView) + 308
#   [bt] (2) 3   libxgboost.dylib                    0x00000001695fa06c xgboost::GetMissing(xgboost::Json const&) + 268
#   [bt] (3) 4   libxgboost.dylib                    0x00000001696149a0 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 140
#   [bt] (4) 5   libxgboost.dylib                    0x00000001696152dc XGBoosterPredictFromDense + 436
#   [bt] (5) 6   libffi.dylib                        0x00000001a0c66050 ffi_call_SYSV + 80
#   [bt] (6) 7   libffi.dylib                        0x00000001a0c6eaf8 ffi_call_int + 1208
#   [bt] (7) 8   _ctypes.cpython-311-darwin.so       0x000000010249416c _ctypes_callproc + 1372
#   [bt] (8) 9   _ctypes.cpython-311-darwin.so       0x000000010248e164 PyCFuncPtr_call + 204
#
#
#
#   warnings.warn(

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[56854     7]
#  [   19    82]]

# %% [markdown]
# # Part 6: Predicting a single observation

# %%
print(dataset.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
single_obs = [[]]

# %%
classifier.predict(sc.transform(single_obs))
# non fraud transaction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/yaseerarafatkhan/Downloads/Machine Learning & Deep Learning Projects for Beginners 2023/DEEP LEARNING Projects/6) Credit card Fraud detection/Project_6_Credit_card_fraud_detection.ipynb Cell 89 line 1
# ----> <a href='vscode-notebook-cell:/Users/yaseerarafatkhan/Downloads/Machine%20Learning%20%26%20Deep%20Learning%20Projects%20for%20Beginners%202023/DEEP%20LEARNING%20Projects/6%29%20Credit%20card%20Fraud%20detection/Project_6_Credit_card_fraud_detection.ipynb#Y164sZmlsZQ%3D%3D?line=0'>1</a> classifier.predict(sc.transform(single_obs))
#       <a href='vscode-notebook-cell:/Users/yaseerarafatkhan/Downloads/Machine%20Learning%20%26%20Deep%20Learning%20Projects%20for%20Beginners%202023/DEEP%20LEARNING%20Projects/6%29%20Credit%20card%20Fraud%20detection/Project_6_Credit_card_fraud_detection.ipynb#Y164sZmlsZQ%3D%3D?line=1'>2</a> # non fraud transaction
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:1004, in StandardScaler.transform(self, X, copy)
#    1001 check_is_fitted(self)
#    1003 copy = copy if copy is not None else self.copy
# -> 1004 X = self._validate_data(
#    1005     X,
#    1006     reset=False,
#    1007     accept_sparse="csr",
#    1008     copy=copy,
#    1009     dtype=FLOAT_DTYPES,
#    1010     force_all_finite="allow-nan",
#    1011 )
#    1013 if sparse.issparse(X):
#    1014     if self.with_mean:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:978, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     976     n_features = array.shape[1]
#     977     if n_features < ensure_min_features:
# --> 978         raise ValueError(
#     979             "Found array with %d feature(s) (shape=%s) while"
#     980             " a minimum of %d is required%s."
#     981             % (n_features, array.shape, ensure_min_features, context)
#     982         )
#     984 if copy:
#     985     if _is_numpy_namespace(xp):
#     986         # only make a copy if `array` and `array_orig` may share memory`
#
# ValueError: Found array with 0 feature(s) (shape=(1, 0)) while a minimum of 1 is required by StandardScaler.
